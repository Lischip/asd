# %% [markdown]
# # Behaviourplots
# KPI:
# - Cost of Illness
# - Contaminated chicken meat
# - DALY
#
# TODO:
# - better kinds of plots for the yearly KPIs (COI and Daly)
# - fix ticks for plots of contaminated meat

# %% [markdown]
# base and wc: base, 12<br/>
# population: 1-3<br/>
# temperature: 4-6<br/>
# seasonal: 7-8<br/>
# public health: 9-10<br/>

# %% [markdown]
# ## Are there any Nans?

# %%
location = "../data/cb_data.txt"
df = pd.read_csv(location, delimiter="\t", dtype="string")
df = df.iloc[:, :-1]
null_data = df[df.isnull().any(axis=1)]
null_data.Date.values
# Out:
# <StringArray>
# []
# Length: 0, dtype: string

# %%
df.shape
# Out:
# (65, 24002)

# %%
df.Date.values
# Out:
# <StringArray>
# [                           'contaminated meat : cb_scen_12',
#                             'contaminated meat : cb_scen_11',
#                             'contaminated meat : cb_scen_10',
#                              'contaminated meat : cb_scen_9',
#                              'contaminated meat : cb_scen_8',
#                              'contaminated meat : cb_scen_7',
#                              'contaminated meat : cb_scen_6',
#                              'contaminated meat : cb_scen_5',
#                              'contaminated meat : cb_scen_4',
#                              'contaminated meat : cb_scen_3',
#                              'contaminated meat : cb_scen_2',
#                              'contaminated meat : cb_scen_1',
#                           'contaminated meat : cb_scen_base',
#                               'Cost of Illness : cb_scen_12',
#                               'Cost of Illness : cb_scen_11',
#                               'Cost of Illness : cb_scen_10',
#                                'Cost of Illness : cb_scen_9',
#                                'Cost of Illness : cb_scen_8',
#                                'Cost of Illness : cb_scen_7',
#                                'Cost of Illness : cb_scen_6',
#                                'Cost of Illness : cb_scen_5',
#                                'Cost of Illness : cb_scen_4',
#                                'Cost of Illness : cb_scen_3',
#                                'Cost of Illness : cb_scen_2',
#                                'Cost of Illness : cb_scen_1',
#                             'Cost of Illness : cb_scen_base',
#                                          'DALY : cb_scen_12',
#                                          'DALY : cb_scen_11',
#                                          'DALY : cb_scen_10',
#                                           'DALY : cb_scen_9',
#                                           'DALY : cb_scen_8',
#                                           'DALY : cb_scen_7',
#                                           'DALY : cb_scen_6',
#                                           'DALY : cb_scen_5',
#                                           'DALY : cb_scen_4',
#                                           'DALY : cb_scen_3',
#                                           'DALY : cb_scen_2',
#                                           'DALY : cb_scen_1',
#                                        'DALY : cb_scen_base',
#              'human infection from environment : cb_scen_12',
#              'human infection from environment : cb_scen_11',
#              'human infection from environment : cb_scen_10',
#               'human infection from environment : cb_scen_9',
#               'human infection from environment : cb_scen_8',
#               'human infection from environment : cb_scen_7',
#               'human infection from environment : cb_scen_6',
#               'human infection from environment : cb_scen_5',
#               'human infection from environment : cb_scen_4',
#               'human infection from environment : cb_scen_3',
#               'human infection from environment : cb_scen_2',
#               'human infection from environment : cb_scen_1',
#            'human infection from environment : cb_scen_base',
#    'rate of chicken infection from environment : cb_scen_12',
#    'rate of chicken infection from environment : cb_scen_11',
#    'rate of chicken infection from environment : cb_scen_10',
#     'rate of chicken infection from environment : cb_scen_9',
#     'rate of chicken infection from environment : cb_scen_8',
#     'rate of chicken infection from environment : cb_scen_7',
#     'rate of chicken infection from environment : cb_scen_6',
#     'rate of chicken infection from environment : cb_scen_5',
#     'rate of chicken infection from environment : cb_scen_4',
#     'rate of chicken infection from environment : cb_scen_3',
#     'rate of chicken infection from environment : cb_scen_2',
#     'rate of chicken infection from environment : cb_scen_1',
#  'rate of chicken infection from environment : cb_scen_base']
# Length: 65, dtype: string

# %% [markdown]
# # AIght

# %%
bw = ["1", "12"]
po = ["1", "2", "3"]
t = ["4", "5", "6"]
s = ["7","8"]
pu = ["9", "10"]

# %%
policydict = {"cb" : "Consumption behaviour",
             "fs" : "Food safety",
             "pc": "Pest control",
             "fe": "Fly exposure",
             "ss" : "Safe slaughtering"}

# %%
# What scenarios do u want plotted from policy?
scenarios = po

# What scenarios from base?
base_scenarios = po

# %%
#What's the name of ur file?
loc = "cb_data"

# %%
#What's ur policy called?
policy = policydict[loc[:2]]
# Out:
# 'Consumption behaviour'

# %% [markdown]
# ## Everything below only needs to be run

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")
from enum import Enum

# %%
num_scen = len(scenarios) if len(scenarios)> len(base_scenarios) else len(base_scenarios)

# %%
namedict = {"base": "base",
            "1": "Population: medium increase",
            "2": "Population: large increase",
            "3": "Population: decrease",
            "4": "Temperature: increase 1 degree",
            "5": "Temperature: increase 1.5 degrees",
            "6": "Temperature: increase 2 degrees",
            "7": "Seasonality: no temperature change",
            "8": "Seasonality: Fast temperature change",
            "9": "Seasonality: linear temperature change",
            "10": "Public health: 10% fewer symptoms",
            "11": "Public health: 10% more symptoms",
            "12": "Worst case"}

class DATA(Enum):
    COI = "Cost of Illness"
    DALY = "DALY"
    COIACC = "aCost of Illness"
    DALYACC = "aDALY"
    MEAT = "contaminated meat"
    ENVH = "human infection from environment"
    ENVC = "rate of chicken infection from environment"

# %%
def _processing(df, scenarios):
    global namedict
    df = df.loc[df.index.str.split("_").str[-1].isin(scenarios)].T
    df.columns = scenarios
    df.columns = df.columns.to_series().apply(lambda value: namedict[value.split("_")[-1]])
    df.index =df.index.astype("float")
    return df
    
def _coi_processing(df, scenarios):
    df = _processing(df, scenarios)
    # get each year
    df = df[df.index % 1 == 0].copy()
    # only care about the difference
    return df.diff(axis=0)

def _meat_processing(df, scenarios):
    df = _processing(df, scenarios)
    if df.empty:
        return df
    min_idx, max_idx = min(df.index), max(df.index)
    #for truncation
    df = df.groupby(np.arange(len(df))//4, as_index=False).mean()
    idx = pd.DataFrame(np.arange(min_idx, max_idx, (max_idx - min_idx)/df.shape[0]))
    df = pd.concat([idx, df], axis=1)
    df.set_index(0, inplace = True)
    df.index.name = None
    df.index =df.index.astype("float")
    return df

def data_processing(loc):
    location = "../data/" + loc + ".txt"
    df = pd.read_csv(location, delimiter="\t", dtype="string")
    df = df.iloc[:, :-1]
    df.fillna("0")
    # Ok, so as we all know Python is retarded when it comes to memory allocation, which means we have to resort ugly constructs like this
    temp = df.iloc[:, 1:].applymap(lambda value: str(float(value.replace("M",'')) * 1000000) if "M" in value else value)
    temp = temp.apply(pd.to_numeric)
    df = pd.concat([df.iloc[:, 0], temp], axis=1)
    #df = pd.DataFrame(df.iloc[:,0]).join(temp)
    df.set_index("Date", inplace=True)
    return df

def get_data(data, df, scenarios):

    if data.name in [DATA.COI.name, DATA.DALY.name]:
        df = pd.DataFrame(df.loc[data_df.index.str.contains(data.value)])
        return _coi_processing(df, scenarios)
    elif data.name in [DATA.COIACC.name, DATA.DALYACC.name]:
        df = pd.DataFrame(df.loc[data_df.index.str.contains(data.value[1:])])
        return _meat_processing(df, scenarios)
    else:
        df = pd.DataFrame(df.loc[data_df.index.str.contains(data.value)])
        return _meat_processing(df, scenarios)

# %%
# Because we like colour consistency
simulcmap = "viridis"
cmap = plt.cm.get_cmap(simulcmap, len(namedict))
cmapcolors = cmap(range(len(namedict)))
colors = np.array([list(cmapcolors[int(x)]) if x != "base" else list(cmapcolors[0]) for x in scenarios])
colors_base = np.array([list(cmapcolors[int(x)]) if x != "base" else list(cmapcolors[0]) for x in base_scenarios])

# %%
data_df = data_processing(loc)

# %%
base_df = data_processing("00_data")

# %% [markdown]
# ## Cost of Illness

# %%
policy_coi = get_data(DATA.COI, data_df, scenarios)
base_coi = get_data(DATA.COI, base_df, base_scenarios)
policy_coi = policy_coi.reindex(base_coi.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

if policy_coi.shape[1] >= 1:
    sns.lineplot(data=policy_coi[2022:], palette=colors, dashes=[(1, 0)] * len(scenarios))
if base_coi.shape[1] >= 1:
    sns.lineplot(data=base_coi[2022:], palette=colors_base, dashes=[(1, 4)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Euro')
plt.title(policy + ': Cost of Illness')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.13 - (0.02 * num_scen), 1, 1),
           loc="lower center")

plt.savefig("../images/" + loc[:2] + "_" + name +"_coi.png", dpi=300, bbox_inches='tight')
plt.show()
del policy_coi
del base_coi

# %% [markdown]
# ## Accumulated Cost of Illness

# %%
policy_coi = get_data(DATA.COIACC, data_df, scenarios)
base_coi = get_data(DATA.COIACC, base_df, base_scenarios)
policy_coi = policy_coi.reindex(base_coi.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

if policy_coi.shape[1] >= 1:
    sns.lineplot(data=policy_coi.loc[policy_coi.index >= 2021.75], palette=colors, dashes=[(1, 0)] * len(scenarios))
if base_coi.shape[1] >= 1:
    sns.lineplot(data=base_coi.loc[base_coi.index >= 2021.75], palette=colors_base,
                 dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Euro')
plt.title(policy + ': Accumulated Cost of Illness')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.16 - (0.02 * num_scen), 1, 1),
           loc="lower center")
ax.grid(True)
plt.savefig("../images/" + loc[:2] + "_" + name  + "_acoi.png", dpi=300, bbox_inches='tight')
plt.show()
del policy_coi
del base_coi

# %% [markdown]
# ## Contaminated chicken meat

# %%
policy_meat = get_data(DATA.MEAT, data_df, scenarios)
base_meat = get_data(DATA.MEAT, base_df, base_scenarios)
policy_meat = policy_meat.reindex(base_meat.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

if policy_meat.shape[1] >= 1:
    sns.lineplot(data=policy_meat.loc[policy_meat.index >= 2021.75], palette=colors, dashes=[(1, 0)] * len(scenarios))
if base_meat.shape[1] >= 1:
    sns.lineplot(data=base_meat.loc[base_meat.index >= 2021.75], palette=colors_base,
                 dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Kg')
plt.title(policy + ': Contaminated chicken meat')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.13 - (0.02 * num_scen), 1, 1),
           loc="lower center")
ax.grid(True)
plt.savefig("../images/" + loc[:2] + "_" + name +"_meat.png", dpi=300, bbox_inches='tight')
plt.show()
del policy_meat
del base_meat

# %% [markdown]
# ## Human infection from environment

# %%
policy_envh = get_data(DATA.ENVH, data_df, scenarios)
base_envh = get_data(DATA.ENVH, base_df, base_scenarios)
policy_envh = policy_envh.reindex(base_envh.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.lineplot(data=policy_envh.loc[policy_envh.index >= 2021.75], palette=colors, dashes=[(1, 0)] * len(scenarios))
sns.lineplot(data=base_envh.loc[base_envh.index >= 2021.75], palette=colors_base,
             dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Persons')
plt.title(policy + ': Humans infected by environment')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.16 - (0.02 * num_scen), 1, 1),
           loc="lower center")
ax.grid(True)
plt.savefig("../images/" + loc[:2] + "_" + name + "_humaninfection.png", dpi=300, bbox_inches='tight')
plt.show()
del policy_envh
del base_envh

# %% [markdown]
# ## Infection from envrionment for chicken

# %%
policy_envc = get_data(DATA.ENVC, data_df, scenarios)
base_envc = get_data(DATA.ENVC, base_df, base_scenarios)
policy_envc = policy_envc.reindex(base_envc.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.lineplot(data=policy_envc.loc[policy_envc.index >= 2021.75], palette=colors, dashes=[(1, 0)] * len(scenarios))
sns.lineplot(data=base_envc.loc[base_envc.index >= 2021.75], palette=colors_base,
             dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Ratio')
plt.title(policy + ': Ratio of chickens infected by environment')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.16 - (0.02 * num_scen), 1, 1),
           loc="lower center")
ax.grid(True)
plt.savefig("../images/" + loc[:2] + "_" + name + "_chickeninfection.png", dpi=300, bbox_inches='tight')
plt.show()

del policy_envc
del base_envc

# %% [markdown]
# ## DECOMMISSIONED DALY

# %%
policy_daly = get_data(DATA.DALY, data_df, scenarios)
base_daly = get_data(DATA.DALY, base_df, base_scenarios)
policy_daly = policy_daly.reindex(base_daly.columns, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

if policy_daly.shape[1] >= 1:
    sns.lineplot(data=policy_daly[2022:], palette=colors, dashes=[(1, 0)] * len(scenarios))
if base_daly.shape[1] >= 1:
    sns.lineplot(data=base_daly[2022:], palette=colors_base, dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year');
plt.ylabel('Euro')
plt.title(policy + ': DALYs')

plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.16 - (0.02 * num_scen), 1, 1),
           loc="lower center")
ax.grid(True)

plt.savefig("../images/" + loc[:2] + "_" + name + "_daly.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Accumulated DALYs

# %%
policy_daly = get_data(DATA.DALYACC, data_df, scenarios)
base_daly = get_data(DATA.DALYACC, base_df, base_scenarios)
policy_daly = policy_daly.reindex(base_daly.columns, axis=1)
# Out:
# DALYACC
# DALY
# DALYACC
# DALY

# %%
fig, ax = plt.subplots(figsize = (10,10))

if policy_daly.shape[1] >= 1:
    sns.lineplot(data=policy_daly.loc[policy_daly.index >= 2021.75], palette=colors, dashes=[(1, 0)] * len(scenarios))
if base_daly.shape[1] >= 1:
    sns.lineplot(data=base_daly.loc[base_daly.index >= 2021.75], palette=colors_base, dashes=[(4, 2)] * len(base_scenarios))

plt.xlabel('Year'); plt.ylabel('Euro')
plt.title(policy + ': Accumulated DALYs')
plt.legend(title="Scenarios", ncol=2, fancybox=True, bbox_to_anchor=(0, -0.16-(0.02*num_scen), 1, 1), loc="lower center")
ax.grid(True)
plt.savefig("../images/" + loc[:2] + "_" + name + "_adaly.png", dpi=300, bbox_inches='tight')
plt.show()
del policy_daly
del base_daly
